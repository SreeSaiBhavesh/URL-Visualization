# %%
pip install yarl
# Out:
# Requirement already satisfied: yarl in /usr/local/lib/python3.10/dist-packages (1.9.2)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.10/dist-packages (from yarl) (6.0.4)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl) (3.4)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from yarl import URL
url = URL("https://github.com/search?q=data+science")

# %%
url.scheme
# Out:
# 'https'

# %%
import pandas as pd
data = pd.read_csv("/content/gdrive/MyDrive/Datasets/URL Classification.csv", names=["url", "Type"], index_col=0)

# %%
sample = data.sample(10000, random_state=1)
sample.head(10)
# Out:
#                                                        url       Type
# 1308349                      http://yorkrite.com/ne/gcram/    Society
# 276825              http://www.alliedartistsofamerica.org/       Arts
# 1315267    http://www.msstate.edu/org/farmhouse/index.html    Society
# 392387                         http://www.sunnytec.com.tw/   Business
# 1267730                             http://www.kabissa.org    Society
# 1392788         http://www.newadvent.org/cathen/12134b.htm    Society
# 672881   http://www.gamespot.com/ps2/driving/arcticthun...      Games
# 1526125                          http://www.studsquad.net/     Sports
# 1009901                            http://www.spacedog.biz  Reference
# 330964                     http://www.meditrans-japan.com/   Business

# %%
sample["url"] = sample["url"].apply(lambda url: URL(url))

processed = sample.assign(
    host=sample.url.apply(lambda url: url.host),
    path=sample.url.apply(lambda url: url.path),
    name=sample.url.apply(lambda url: url.name),
    scheme=sample.url.apply(lambda url: url.scheme),
    query=sample.url.apply(lambda url: url.query_string),
)
processed
# Out:
#                                                      url      Type  \
# 1308349                    http://yorkrite.com/ne/gcram/   Society
# 276825            http://www.alliedartistsofamerica.org/      Arts
# 1315267  http://www.msstate.edu/org/farmhouse/index.html   Society
# 392387                       http://www.sunnytec.com.tw/  Business
# 1267730                           http://www.kabissa.org   Society
# ...                                                  ...       ...
# 169463        http://www.naxos.com/composerinfo/3303.htm      Arts
# 1094461              http://members.tripod.com/arroweb1/   Science
# 526843                       http://www.petroskills.com/  Business
# 171473                    http://www.gregbartholomew.com      Arts
# 277393                           http://www.denysart.com      Arts
#
#                                    host                       path  \
# 1308349                    yorkrite.com                 /ne/gcram/
# 276825   www.alliedartistsofamerica.org                          /
# 1315267                 www.msstate.edu  /org/farmhouse/index.html
# 392387              www.sunnytec.com.tw                          /
# 1267730                 www.kabissa.org                          /
# ...                                 ...                        ...
# 169463                    www.naxos.com     /composerinfo/3303.htm
# 1094461              members.tripod.com                 /arroweb1/
# 526843              www.petroskills.com                          /
# 171473          www.gregbartholomew.com                          /
# 277393                 www.denysart.com                          /
#
#                name scheme query
# 1308349               http
# 276825                http
# 1315267  index.html   http
# 392387                http
# 1267730               http
# ...             ...    ...   ...
# 169463     3303.htm   http
# 1094461               http
# 526843                http
# 171473                http
# 277393                http
#
# [10000 rows x 7 columns]

# %%
group = processed.groupby(["Type", "host"]).agg(count=("url", "count"))

# Get the top 5 most popular hosts for each type
sorted_group = group.sort_values(by="count", ascending=False).reset_index()
largest = sorted_group.groupby("Type").head(5).sort_values(by='Type')

# View the bottom 10 rows
largest.tail(10)
# Out:
#        Type                       host  count
# 17  Society         members.tripod.com     12
# 25  Society           en.wikipedia.org      9
# 7   Society          www.angelfire.com     25
# 3   Society          www.geocities.com     56
# 1   Society          www.newadvent.org     91
# 35   Sports  sportsillustrated.cnn.com      7
# 11   Sports          www.geocities.com     18
# 45   Sports      www.clubwebsite.co.uk      6
# 50   Sports          www.angelfire.com      6
# 47   Sports           www.freewebs.com      6

# %%
pip install graphistry
# Out:
# Collecting graphistry
#   Downloading graphistry-0.29.6-py3-none-any.whl (228 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.6/228.6 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from graphistry) (1.23.5)
# Collecting palettable>=3.0 (from graphistry)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from graphistry) (1.5.3)
# Requirement already satisfied: pyarrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from graphistry) (9.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from graphistry) (2.31.0)
# Collecting squarify (from graphistry)
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from graphistry) (4.5.0)
# Requirement already satisfied: packaging>=20.1 in /usr/local/lib/python3.10/dist-packages (from graphistry) (23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from graphistry) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->graphistry) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->graphistry) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->graphistry) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->graphistry) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->graphistry) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->graphistry) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->graphistry) (1.16.0)
# Installing collected packages: squarify, palettable, graphistry
# Successfully installed graphistry-0.29.6 palettable-3.3.3 squarify-0.4.3

# %%
import graphistry

graphistry.register(api=3, username='#######', password='########')

# %%
edges = largest[["Type", "host"]]

# %%
def create_node_df(df: pd.DataFrame, col_name: str):
  nodes = (
        df[[col_name]]
        .assign(type=col_name)
        .rename(columns={col_name: "node"})
        .drop_duplicates()
  )
  return nodes


type_nodes = create_node_df(largest, "Type")
url_nodes = create_node_df(largest, "host")
nodes = pd.concat([type_nodes, url_nodes])
nodes
# Out:
#                                node  type
# 115                           Adult  Type
# 12                             Arts  Type
# 114                        Business  Type
# 9                         Computers  Type
# 41                            Games  Type
# 127                          Health  Type
# 18                             Home  Type
# 111                            Kids  Type
# 1343                           News  Type
# 4                        Recreation  Type
# 66                        Reference  Type
# 48                          Science  Type
# 307                        Shopping  Type
# 17                          Society  Type
# 35                           Sports  Type
# 115            www.realgoodporn.com  host
# 286            www.almightyzeus.com  host
# 134               www.angelfire.com  host
# 94                 groups.yahoo.com  host
# 77                www.geocities.com  host
# 12                     www.imdb.com  host
# 8                members.tripod.com  host
# 5                       us.imdb.com  host
# 201              www.cs.arizona.edu  host
# 229                 www.autexrj.org  host
# 165                     www.pwc.com  host
# 9                    tools.ietf.org  host
# 129                 sourceforge.net  host
# 49                 en.wikipedia.org  host
# 41                 www.gamefaqs.com  host
# 52               www.gaming-age.com  host
# 10                 www.gamespot.com  host
# 127               www.ninds.nih.gov  host
# 14                   www.rxlist.com  host
# 126                 www.nlm.nih.gov  host
# 18             www.recipesource.com  host
# 99               www.recipezaar.com  host
# 111                    kids.aol.com  host
# 109                 uk.gamespot.com  host
# 28                 www.freewebs.com  host
# 1343             www.oregonlive.com  host
# 1341                 www.pgpost.com  host
# 1340        www.postindependent.com  host
# 1339  www.scottolsonphotography.com  host
# 1342        www.perspectives.ubc.ca  host
# 66                       www.sfu.ca  host
# 110                    flagspot.net  host
# 271                   www.smith.edu  host
# 112                     www.uvm.edu  host
# 268                  www.ithaca.edu  host
# 42                  ip30.eti.uva.nl  host
# 21           florawww.eeb.uconn.edu  host
# 729         busypersonscookbook.com  host
# 1                 www.newadvent.org  host
# 35        sportsillustrated.cnn.com  host
# 45            www.clubwebsite.co.uk  host

# %%
g = (
    graphistry
    .edges(edges, "Type", "host")
    .nodes(nodes, "node")
)

g.plot()
# Out:
#             <iframe id="2c95d047-8e27-478b-849f-1b9a143970d4" src="https://hub.graphistry.com/graph/graph.html?dataset=bf285350ed794d4db9f8c613d0ab2cb8&type=arrow&viztoken=483414b4-7093-4ee9-85ac-85abeaf5e093&usertag=82f2389b-pygraphistry-0.29.6&splashAfter=1697622657&info=true"
#                     allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true"
#                     oallowfullscreen="true" msallowfullscreen="true"
#                     style="width:100%; height:500px; border: 1px solid #DDD; overflow: hidden"
#
#             >
#             </iframe>
#
#             <script>
#                 try {
#                   $("#2c95d047-8e27-478b-849f-1b9a143970d4").bind('mousewheel', function(e) { e.preventDefault(); });
#                 } catch (e) { console.error('exn catching scroll', e); }
#             </script>

# %%
pip install faker
# Out:
# Collecting faker
#   Downloading Faker-19.10.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-19.10.0

# %%
from faker import Faker

types = list(edges.Type.unique())

fake = Faker()
colors = [fake.color() for _ in range(len(types))]
node_color_mapping = dict(zip(types, colors))
node_color_mapping
# Out:
# {'Adult': '#9023c6',
#  'Arts': '#eda097',
#  'Business': '#ea7344',
#  'Computers': '#ea9570',
#  'Games': '#f0ffb2',
#  'Health': '#078450',
#  'Home': '#6639ba',
#  'Kids': '#238189',
#  'News': '#ffd0c4',
#  'Recreation': '#2ea0a0',
#  'Reference': '#fcf294',
#  'Science': '#473899',
#  'Shopping': '#93f9b0',
#  'Society': '#78b9e8',
#  'Sports': '#14d166'}

# %%
node_icon_mapping = {"host": "link", "Type": "newspaper-o"}

# %%
g = (
    graphistry.edges(edges, "Type", "host")
    .nodes(nodes, "node")
    .encode_point_color(
        "node", categorical_mapping=node_color_mapping, default_mapping="silver"
    )
    .encode_point_icon(
        "type", categorical_mapping=node_icon_mapping
    )
)

g.plot()
# Out:
#             <iframe id="e3c19120-ed13-45c0-a36d-aee74cf6e849" src="https://hub.graphistry.com/graph/graph.html?dataset=0d6299c91ae34df3b333db907ba44ca4&type=arrow&viztoken=efb4ac6b-7d67-4528-a86e-4d313836b094&usertag=82f2389b-pygraphistry-0.29.6&splashAfter=1697622670&info=true"
#                     allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true"
#                     oallowfullscreen="true" msallowfullscreen="true"
#                     style="width:100%; height:500px; border: 1px solid #DDD; overflow: hidden"
#
#             >
#             </iframe>
#
#             <script>
#                 try {
#                   $("#e3c19120-ed13-45c0-a36d-aee74cf6e849").bind('mousewheel', function(e) { e.preventDefault(); });
#                 } catch (e) { console.error('exn catching scroll', e); }
#             </script>
